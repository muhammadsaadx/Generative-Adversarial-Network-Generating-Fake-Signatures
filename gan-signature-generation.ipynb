# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

# %%
# Parameters
n_epochs = 500
noise_dim = 64
display_step = 500
batch_size = 128
lr = 0.00001
device = 'cuda' if torch.cuda.is_available() else 'cpu'
image_dim = 64 * 64 * 3  # Updated for 64x64 RGB images

# %%
# Define transformations
transform = transforms.Compose([
    transforms.Resize((64, 64)),  # Ensure images are 64x64
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Load the custom dataset
dataset_path = '/kaggle/input/inverted-cropped-images/Inverted_Cropped_Images'
custom_dataset = ImageFolder(root=dataset_path, transform=transform)
dataloader = DataLoader(custom_dataset, batch_size=batch_size, shuffle=True)

# Function to show images
def show_tensor_images(image_tensor, num_images=25, size=(3, 64, 64)):
    '''
    Function for visualizing images: Given a tensor of images, number of images, and
    size per image, plots and prints the images in a uniform grid.
    '''
    image_unflat = image_tensor.detach().cpu().view(-1, *size)
    image_grid = make_grid(image_unflat[:num_images], nrow=5)
    plt.imshow(image_grid.permute(1, 2, 0).squeeze())
    plt.show()

# %%
# Generator Class
class Generator(nn.Module):
    def __init__(self, noise_dim=10, image_dim=64*64*3, hidden_dim=128):
        super(Generator, self).__init__()
        self.block1 = nn.Sequential(
            nn.Linear(noise_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True)
        )
        self.block2 = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.BatchNorm1d(hidden_dim * 2),
            nn.ReLU(inplace=True)
        )
        self.block3 = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim * 4),
            nn.BatchNorm1d(hidden_dim * 4),
            nn.ReLU(inplace=True)
        )
        self.block4 = nn.Sequential(
            nn.Linear(hidden_dim * 4, hidden_dim * 8),
            nn.BatchNorm1d(hidden_dim * 8),
            nn.ReLU(inplace=True)
        )
        self.block5 = nn.Sequential(
            nn.Linear(hidden_dim * 8, image_dim),
            nn.Sigmoid()
        )
    
    def forward(self, noise):
        out = self.block1(noise)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        return out

# Discriminator Class
class Discriminator(nn.Module):
    def __init__(self, image_dim=64*64*3, hidden_dim=128):
        super(Discriminator, self).__init__()
        self.block1 = nn.Sequential(
            nn.Linear(image_dim, hidden_dim * 4),
            nn.LeakyReLU(negative_slope=.2)
        )
        self.block2 = nn.Sequential(
            nn.Linear(hidden_dim * 4, hidden_dim * 2),
            nn.LeakyReLU(negative_slope=.2)
        )
        self.block3 = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LeakyReLU(negative_slope=.2)
        )
        self.block4 = nn.Linear(hidden_dim, 1)
    
    def forward(self, image):
        out = self.block1(image)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        return out

# %%
# Noise generator
def get_noise(number_samples, noise_dim, device):
    return torch.randn(number_samples, noise_dim, device=device)

# Discriminator Loss
def disc_loss(gen, disc, criterion, original, num_images, noise_dim, device):
    noise_vec = get_noise(num_images, noise_dim, device)
    gen_image = gen(noise_vec).detach()
    gen_labels = torch.zeros(num_images, 1, device=device)
    gen_pred = disc(gen_image)
    gen_img_loss = criterion(gen_pred, gen_labels)
    org_labels = torch.ones(num_images, 1, device=device)
    org_pred = disc(original)
    org_img_loss = criterion(org_pred, org_labels)
    disc_loss = (org_img_loss + gen_img_loss) / 2
    return disc_loss

# Generator Loss
def gen_loss(gen, disc, criterion, num_images, noise_dim, device):
    noise_vec = get_noise(num_images, noise_dim, device)
    gen_img = gen(noise_vec)
    gen_img_pred = disc(gen_img)
    gen_labels = torch.ones(num_images, 1, device=device)
    gen_loss = criterion(gen_img_pred, gen_labels)
    return gen_loss

# Model initialization
gen = Generator(noise_dim=noise_dim, image_dim=image_dim).to(device)
disc = Discriminator(image_dim=image_dim).to(device)
gen_opt = torch.optim.Adam(gen.parameters(), lr=lr)
disc_opt = torch.optim.Adam(disc.parameters(), lr=lr)
criterion = nn.BCEWithLogitsLoss()

# Training loop
cur_step = 0
mean_generator_loss = 0
mean_discriminator_loss = 0

# %%
for epoch in range(n_epochs):
    for org, _ in tqdm(dataloader):
        cur_batch_size = len(org)
        org = org.view(cur_batch_size, -1).to(device)

        # Update discriminator
        disc_opt.zero_grad()
        discriminator_loss = disc_loss(gen, disc, criterion, org, cur_batch_size, noise_dim, device)
        discriminator_loss.backward(retain_graph=True)
        disc_opt.step()

        # Update generator
        gen_opt.zero_grad()
        generator_loss = gen_loss(gen, disc, criterion, cur_batch_size, noise_dim, device)
        generator_loss.backward(retain_graph=True)
        gen_opt.step()

        mean_discriminator_loss += discriminator_loss.item() / display_step
        mean_generator_loss += generator_loss.item() / display_step

        # Display generated images
        if cur_step % display_step == 0 and cur_step > 0:
            print(f'Epoch {epoch}, step {cur_step} -> Generator loss: {mean_generator_loss}, Discriminator loss: {mean_discriminator_loss}')
            gen_noise = get_noise(cur_batch_size, noise_dim, device=device)
            generated = gen(gen_noise)
            show_tensor_images(generated, size=(3, 64, 64))
            show_tensor_images(org, size=(3, 64, 64))
            mean_generator_loss = 0
            mean_discriminator_loss = 0
        cur_step += 1
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 7, step 500 -> Generator loss: 3.7973862313032205, Discriminator loss: 0.03589359314180905
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 15, step 1000 -> Generator loss: 3.604214439392091, Discriminator loss: 0.016137716669589276
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 23, step 1500 -> Generator loss: 2.9646502408981332, Discriminator loss: 0.029935841225087648
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 31, step 2000 -> Generator loss: 2.880659937381745, Discriminator loss: 0.030964811492711304
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 39, step 2500 -> Generator loss: 3.398983089923857, Discriminator loss: 0.01790773963369428
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 46, step 3000 -> Generator loss: 4.162795698642731, Discriminator loss: 0.008155762623064224
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 54, step 3500 -> Generator loss: 4.899926548957823, Discriminator loss: 0.0038381178309209655
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 62, step 4000 -> Generator loss: 5.546989213943481, Discriminator loss: 0.0019905577062163497
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 70, step 4500 -> Generator loss: 6.112245116233825, Discriminator loss: 0.0011245344962226241
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 78, step 5000 -> Generator loss: 6.615329285621636, Discriminator loss: 0.0006777150941779832
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 85, step 5500 -> Generator loss: 7.0720354919433595, Discriminator loss: 0.00042839013494085516
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch
Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 351, step 22500 -> Generator loss: 17.195074562072744, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 359, step 23000 -> Generator loss: 17.43016452026366, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 367, step 23500 -> Generator loss: 17.661070075988768, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 375, step 24000 -> Generator loss: 17.887857727050786, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 382, step 24500 -> Generator loss: 18.110605766296374, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 390, step 25000 -> Generator loss: 18.329378940582295, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 398, step 25500 -> Generator loss: 18.544242908477816, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 406, step 26000 -> Generator loss: 18.75519691848755, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 414, step 26500 -> Generator loss: 18.962158058166512, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 421, step 27000 -> Generator loss: 19.164988307952896, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 429, step 27500 -> Generator loss: 19.363430789947518, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 437, step 28000 -> Generator loss: 19.55715106964111, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 445, step 28500 -> Generator loss: 19.74572446823118, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 453, step 29000 -> Generator loss: 19.928721469879154, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 460, step 29500 -> Generator loss: 20.105641212463365, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 468, step 30000 -> Generator loss: 20.276003314971945, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 476, step 30500 -> Generator loss: 20.439405635833747, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 484, step 31000 -> Generator loss: 20.595482852935817, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
# Epoch 492, step 31500 -> Generator loss: 20.743928939819302, Discriminator loss: 0.0
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]
#   0%|          | 0/64 [00:00<?, ?it/s]

# %%
torch.save(gen.state_dict(), "generator_model.pth")

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# Define the generator class (same as in the training script)
class Generator(nn.Module):
    def __init__(self, noise_dim=64, image_dim=64*64*3, hidden_dim=128):
        super(Generator, self).__init__()
        self.block1 = nn.Sequential(
            nn.Linear(noise_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(inplace=True)
        )
        self.block2 = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.BatchNorm1d(hidden_dim * 2),
            nn.ReLU(inplace=True)
        )
        self.block3 = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim * 4),
            nn.BatchNorm1d(hidden_dim * 4),
            nn.ReLU(inplace=True)
        )
        self.block4 = nn.Sequential(
            nn.Linear(hidden_dim * 4, hidden_dim * 8),
            nn.BatchNorm1d(hidden_dim * 8),
            nn.ReLU(inplace=True)
        )
        self.block5 = nn.Sequential(
            nn.Linear(hidden_dim * 8, image_dim),
            nn.Sigmoid()
        )
    
    def forward(self, noise):
        out = self.block1(noise)
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        return out

# Function to visualize images
def show_tensor_images(image_tensor, num_images=25, size=(3, 64, 64)):
    image_unflat = image_tensor.detach().cpu().view(-1, *size)
    image_grid = make_grid(image_unflat[:num_images], nrow=5)
    plt.imshow(image_grid.permute(1, 2, 0).squeeze())
    plt.show()

# Load the trained generator model
noise_dim = 64
image_dim = 64 * 64 * 3  # Adjust for 64x64 RGB images
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Initialize the generator and load the saved weights
gen = Generator(noise_dim=noise_dim, image_dim=image_dim).to(device)
gen.load_state_dict(torch.load("generator_model.pth", map_location=device))
gen.eval()

# Generate new images using the generator
num_images = 25  # Number of images to generate
noise = torch.randn(num_images, noise_dim, device=device)
with torch.no_grad():
    generated_images = gen(noise)

# Display the generated images
show_tensor_images(generated_images, num_images=num_images, size=(3, 64, 64))
